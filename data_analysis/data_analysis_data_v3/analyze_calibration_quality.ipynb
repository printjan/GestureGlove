# %% [markdown]
# # Calibration Quality and Sensor Drift Analysis
#
# This notebook analyzes the quality of calibration recordings (verifying user stillness) and tracks the consistency of sensor drift (zero-bias offsets) over time for both IMU1 (Wrist) and IMU2 (Finger).
#
# Specifically, it addresses:
# 1. **Stillness Auditing:** Identifies and flags poor-quality calibrations where the user did not hold still (exceeding standard deviation thresholds).
# 2. **Drift Consistency Analysis:** Tracks zero-bias offsets over consecutive calibrations within the same recording session to understand how fast the sensor drift changes, helping to inform live-calibration strategies.

# %%
import sys
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Resolve paths
PROJECT_ROOT = Path("__file__").resolve().parents[1]
sys.path.append(str(PROJECT_ROOT / "src"))

try:
    from data_fusion_project.core.paths import DATA_DIR
except ImportError:
    DATA_DIR = PROJECT_ROOT / "data"

print(f"Data directory: {DATA_DIR}")
# Out:
# Data directory: /Users/jantischner/Library/CloudStorage/OneDrive-Personal/TH_OHM_B.Sc.Inf/Th-Ohm_B.Sc.Inf_Sem6/DatFus_Sem6_Axenie/DataFusionProject/data/dataset_current

# %%
# Constants and Thresholds for Quality Auditing
# Stillness is audited by checking standard deviation of signals during calibration.
# High standard deviation indicates sensor movement (not holding still).
THRESHOLD_ACC_STD = 0.025  # g-force standard deviation threshold
THRESHOLD_GYR_STD = 3.     # dps (degrees per second) standard deviation threshold

# %%
def parse_calibration_filename(filename):
    """
    Parses the sample count from the calibration filename.
    calibration.csv -> sample_count = 0
    calibration_20.csv -> sample_count = 20
    """
    stem = Path(filename).stem
    if stem == "calibration":
        return 0
    parts = stem.split("_")
    if len(parts) >= 2 and parts[1].isdigit():
        return int(parts[1])
    return 0

# Scan data directory for calibration files
cal_files = sorted(list(DATA_DIR.glob("**/calibration*.csv")))
cal_records = []

for f in cal_files:
    # Get session details from path structure: DATA_DIR / gesture / session / file
    relative = f.relative_to(DATA_DIR)
    parts = relative.parts
    if len(parts) < 3:
        continue
        
    gesture = parts[0]
    session = parts[1]
    name = parts[2]
    
    # Skip temporary files
    if f.name == "calibration.png":
        continue
        
    # Load recording_session.json if exists to get exact sample index
    meta_path = f.parent / "recording_session.json"
    sample_count = None
    if meta_path.exists():
        try:
            with open(meta_path, "r") as json_f:
                import json
                meta = json.load(json_f)
                for entry in meta.get("recalibrations", []):
                    if entry["file"] == f.name:
                        sample_count = entry["sample_index"]
                        break
        except Exception:
            pass
    if sample_count is None:
        sample_count = parse_calibration_filename(f.name)

    cal_records.append({
        'path': f,
        'gesture': gesture,
        'session': session,
        'filename': f.name,
        'sample_count': sample_count
    })

print(f"Found {len(cal_records)} calibration records across data directories.")
# Out:
# Found 102 calibration records across data directories.

# %%
# Audit stillness quality
audited_records = []
poor_calibrations = []

for rec in cal_records:
    try:
        df = pd.read_csv(rec['path'])
        
        # Calculate standard deviation for gyroscope and accelerometer channels
        imu1_acc_std = df[['IMU1_accX', 'IMU1_accY', 'IMU1_accZ']].std().max()
        imu1_gyr_std = df[['IMU1_gyrX', 'IMU1_gyrY', 'IMU1_gyrZ']].std().max()
        imu2_acc_std = df[['IMU2_accX', 'IMU2_accY', 'IMU2_accZ']].std().max()
        imu2_gyr_std = df[['IMU2_gyrX', 'IMU2_gyrY', 'IMU2_gyrZ']].std().max()
        
        # Calculate mean zero-biases (drift offsets)
        imu1_bias = {
            'X': df['IMU1_gyrX'].mean(),
            'Y': df['IMU1_gyrY'].mean(),
            'Z': df['IMU1_gyrZ'].mean()
        }
        imu2_bias = {
            'X': df['IMU2_gyrX'].mean(),
            'Y': df['IMU2_gyrY'].mean(),
            'Z': df['IMU2_gyrZ'].mean()
        }
        
        # Check if thresholds are violated
        failed = False
        reasons = []
        if imu1_acc_std > THRESHOLD_ACC_STD:
            failed = True
            reasons.append(f"IMU1 Acc STD ({imu1_acc_std:.4f}g) > {THRESHOLD_ACC_STD}g")
        if imu1_gyr_std > THRESHOLD_GYR_STD:
            failed = True
            reasons.append(f"IMU1 Gyr STD ({imu1_gyr_std:.2f} dps) > {THRESHOLD_GYR_STD} dps")
        if imu2_acc_std > THRESHOLD_ACC_STD:
            failed = True
            reasons.append(f"IMU2 Acc STD ({imu2_acc_std:.4f}g) > {THRESHOLD_ACC_STD}g")
        if imu2_gyr_std > THRESHOLD_GYR_STD:
            failed = True
            reasons.append(f"IMU2 Gyr STD ({imu2_gyr_std:.2f} dps) > {THRESHOLD_GYR_STD} dps")
            
        rec_data = {
            **rec,
            'imu1_acc_std': imu1_acc_std,
            'imu1_gyr_std': imu1_gyr_std,
            'imu2_acc_std': imu2_acc_std,
            'imu2_gyr_std': imu2_gyr_std,
            'imu1_bias': imu1_bias,
            'imu2_bias': imu2_bias,
            'failed_stillness': failed,
            'reasons': reasons
        }
        audited_records.append(rec_data)
        
        if failed:
            poor_calibrations.append(rec_data)
            
    except Exception as e:
        print(f"Error auditing {rec['filename']} in session {rec['session']}: {e}")

print(f"Audited {len(audited_records)} files.")
print(f"Flagged {len(poor_calibrations)} poor-quality calibrations (user movement detected).")

if poor_calibrations:
    print("\n--- FLAGGED CALIBRATIONS ---")
    for pc in poor_calibrations:
        print(f"Gesture: {pc['gesture']}, Session: {pc['session']}, File: {pc['filename']}")
        print(f"  Reasons: {', '.join(pc['reasons'])}")
# Out:
# Audited 102 files.
# Flagged 1 poor-quality calibrations (user movement detected).
#
# --- FLAGGED CALIBRATIONS ---
# Gesture: none, Session: validation_data, File: calibration_3.csv
#   Reasons: IMU1 Acc STD (0.1616g) > 0.025g, IMU1 Gyr STD (36.83 dps) > 3.0 dps, IMU2 Acc STD (0.0739g) > 0.025g, IMU2 Gyr STD (14.44 dps) > 3.0 dps

# %% [markdown]
# ## Drift Analysis for Multi-Calibration Sessions
#
# Here, we identify sessions that have multiple calibrations (because the session duration exceeded `MAX_SAMPLES_BEFORE_RECALIBRATION` samples, triggering periodic calibration). We analyze zero-bias trends and calculate the drift rate over the course of the session.

# %%
# Group audited records by (gesture, session)
sessions_dict = {}
for r in audited_records:
    key = (r['gesture'], r['session'])
    if key not in sessions_dict:
        sessions_dict[key] = []
    sessions_dict[key].append(r)

# Filter sessions that have multiple calibrations
multi_cal_sessions = {k: sorted(v, key=lambda x: x['sample_count']) for k, v in sessions_dict.items() if len(v) > 1}

print(f"Found {len(multi_cal_sessions)} sessions with multiple calibrations for drift rate tracking.")

for (gesture, session), records in multi_cal_sessions.items():
    print(f"\n======================================================================")
    print(f"Session: {gesture}/{session} ({len(records)} calibrations)")
    print(f"======================================================================")
    
    prev_rec = None
    for i, r in enumerate(records):
        print(f"\nCalibration at sample {r['sample_count']} ({r['filename']}):")
        print(f"  IMU1 (Wrist) Gyro Bias: X={r['imu1_bias']['X']:.3f}, Y={r['imu1_bias']['Y']:.3f}, Z={r['imu1_bias']['Z']:.3f} dps")
        print(f"  IMU2 (Finger) Gyro Bias: X={r['imu2_bias']['X']:.3f}, Y={r['imu2_bias']['Y']:.3f}, Z={r['imu2_bias']['Z']:.3f} dps")
        
        if prev_rec is not None:
            # Calculate change in bias
            step_diff = r['sample_count'] - prev_rec['sample_count']
            
            # IMU1 Bias Changes
            imu1_diff = {axis: r['imu1_bias'][axis] - prev_rec['imu1_bias'][axis] for axis in ['X', 'Y', 'Z']}
            imu1_dist = np.sqrt(sum(d**2 for d in imu1_diff.values()))
            
            # IMU2 Bias Changes
            imu2_diff = {axis: r['imu2_bias'][axis] - prev_rec['imu2_bias'][axis] for axis in ['X', 'Y', 'Z']}
            imu2_dist = np.sqrt(sum(d**2 for d in imu2_diff.values()))
            
            print(f"  -> Drift since sample {prev_rec['sample_count']} (diff: {step_diff} samples):")
            print(f"     IMU1 Bias shift magnitude: {imu1_dist:.4f} dps (rate: {imu1_dist/step_diff:.6f} dps/sample)")
            print(f"     IMU2 Bias shift magnitude: {imu2_dist:.4f} dps (rate: {imu2_dist/step_diff:.6f} dps/sample)")
            
        prev_rec = r
# Out:
# Found 32 sessions with multiple calibrations for drift rate tracking.
#
# ======================================================================
# Session: circle_ccw/session_1782663628 (2 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.445, Y=-1.022, Z=0.518 dps
#   IMU2 (Finger) Gyro Bias: X=1.736, Y=-1.365, Z=0.517 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.370, Y=-1.208, Z=0.496 dps
#   IMU2 (Finger) Gyro Bias: X=2.173, Y=-1.605, Z=0.349 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.2012 dps (rate: 0.008048 dps/sample)
#      IMU2 Bias shift magnitude: 0.5257 dps (rate: 0.021029 dps/sample)
#
# ======================================================================
# Session: circle_ccw/session_1782845686 (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.082, Y=-1.465, Z=0.229 dps
#   IMU2 (Finger) Gyro Bias: X=1.623, Y=-0.842, Z=-0.965 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.119, Y=-1.808, Z=0.337 dps
#   IMU2 (Finger) Gyro Bias: X=1.648, Y=-0.622, Z=-0.872 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.3617 dps (rate: 0.014466 dps/sample)
#      IMU2 Bias shift magnitude: 0.2403 dps (rate: 0.009611 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.120, Y=-1.416, Z=0.390 dps
#   IMU2 (Finger) Gyro Bias: X=1.630, Y=-0.534, Z=-0.810 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.3963 dps (rate: 0.015851 dps/sample)
#      IMU2 Bias shift magnitude: 0.1095 dps (rate: 0.004381 dps/sample)
#
# ======================================================================
# Session: circle_ccw/test_data (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.174, Y=-1.531, Z=0.450 dps
#   IMU2 (Finger) Gyro Bias: X=1.770, Y=-0.534, Z=-0.679 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.255, Y=-0.930, Z=0.555 dps
#   IMU2 (Finger) Gyro Bias: X=1.527, Y=-0.252, Z=-0.744 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.6158 dps (rate: 0.024634 dps/sample)
#      IMU2 Bias shift magnitude: 0.3777 dps (rate: 0.015109 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.309, Y=-1.283, Z=0.369 dps
#   IMU2 (Finger) Gyro Bias: X=1.650, Y=-0.523, Z=-0.792 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.4024 dps (rate: 0.016095 dps/sample)
#      IMU2 Bias shift magnitude: 0.3013 dps (rate: 0.012052 dps/sample)
#
# ======================================================================
# Session: circle_ccw/validation_data (2 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.252, Y=-1.282, Z=0.513 dps
#   IMU2 (Finger) Gyro Bias: X=1.497, Y=-0.331, Z=-0.812 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.100, Y=-1.404, Z=0.523 dps
#   IMU2 (Finger) Gyro Bias: X=1.717, Y=-0.361, Z=-0.938 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1952 dps (rate: 0.007806 dps/sample)
#      IMU2 Bias shift magnitude: 0.2551 dps (rate: 0.010202 dps/sample)
#
# ======================================================================
# Session: circle_cw/session_1782751360 (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.507, Y=-1.232, Z=0.507 dps
#   IMU2 (Finger) Gyro Bias: X=1.640, Y=-0.098, Z=-0.673 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.494, Y=-1.137, Z=0.544 dps
#   IMU2 (Finger) Gyro Bias: X=1.438, Y=-0.448, Z=-0.713 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1030 dps (rate: 0.004121 dps/sample)
#      IMU2 Bias shift magnitude: 0.4062 dps (rate: 0.016248 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.328, Y=-1.149, Z=0.530 dps
#   IMU2 (Finger) Gyro Bias: X=1.436, Y=-0.382, Z=-0.685 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1670 dps (rate: 0.006679 dps/sample)
#      IMU2 Bias shift magnitude: 0.0719 dps (rate: 0.002876 dps/sample)
#
# ======================================================================
# Session: circle_cw/session_1782845304 (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.108, Y=-1.487, Z=0.377 dps
#   IMU2 (Finger) Gyro Bias: X=1.547, Y=-0.678, Z=-0.817 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.144, Y=-1.542, Z=0.274 dps
#   IMU2 (Finger) Gyro Bias: X=1.569, Y=-0.703, Z=-0.898 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1221 dps (rate: 0.004884 dps/sample)
#      IMU2 Bias shift magnitude: 0.0871 dps (rate: 0.003483 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=0.032, Y=-1.542, Z=0.426 dps
#   IMU2 (Finger) Gyro Bias: X=1.692, Y=-0.703, Z=-0.880 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.2328 dps (rate: 0.009311 dps/sample)
#      IMU2 Bias shift magnitude: 0.1244 dps (rate: 0.004976 dps/sample)
#
# ======================================================================
# Session: circle_cw/test_data (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.230, Y=-1.380, Z=0.369 dps
#   IMU2 (Finger) Gyro Bias: X=1.473, Y=-0.648, Z=-0.664 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.352, Y=-1.205, Z=0.425 dps
#   IMU2 (Finger) Gyro Bias: X=1.759, Y=-0.507, Z=-0.744 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.2201 dps (rate: 0.008803 dps/sample)
#      IMU2 Bias shift magnitude: 0.3287 dps (rate: 0.013149 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=0.142, Y=-1.337, Z=0.374 dps
#   IMU2 (Finger) Gyro Bias: X=1.755, Y=-0.565, Z=-1.029 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.5139 dps (rate: 0.020558 dps/sample)
#      IMU2 Bias shift magnitude: 0.2910 dps (rate: 0.011640 dps/sample)
#
# ======================================================================
# Session: circle_cw/validation_data (2 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.250, Y=-1.543, Z=0.466 dps
#   IMU2 (Finger) Gyro Bias: X=1.497, Y=-0.575, Z=-0.652 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.246, Y=-1.429, Z=0.432 dps
#   IMU2 (Finger) Gyro Bias: X=1.711, Y=-0.289, Z=-0.699 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1192 dps (rate: 0.004769 dps/sample)
#      IMU2 Bias shift magnitude: 0.3600 dps (rate: 0.014400 dps/sample)
#
# ======================================================================
# Session: fist/session_1782751666 (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.535, Y=-0.814, Z=0.563 dps
#   IMU2 (Finger) Gyro Bias: X=1.560, Y=-0.192, Z=-0.603 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.336, Y=-1.077, Z=0.561 dps
#   IMU2 (Finger) Gyro Bias: X=1.461, Y=0.094, Z=-0.632 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.3298 dps (rate: 0.013193 dps/sample)
#      IMU2 Bias shift magnitude: 0.3035 dps (rate: 0.012140 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.370, Y=-1.047, Z=0.566 dps
#   IMU2 (Finger) Gyro Bias: X=1.544, Y=-0.029, Z=-0.532 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.0460 dps (rate: 0.001839 dps/sample)
#      IMU2 Bias shift magnitude: 0.1784 dps (rate: 0.007134 dps/sample)
#
# ======================================================================
# Session: fist/session_1782830502 (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.455, Y=-1.044, Z=0.437 dps
#   IMU2 (Finger) Gyro Bias: X=1.444, Y=-1.074, Z=-0.637 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.465, Y=-1.007, Z=0.424 dps
#   IMU2 (Finger) Gyro Bias: X=1.392, Y=-1.034, Z=-0.559 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.0407 dps (rate: 0.001628 dps/sample)
#      IMU2 Bias shift magnitude: 0.1013 dps (rate: 0.004053 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.460, Y=-1.007, Z=0.469 dps
#   IMU2 (Finger) Gyro Bias: X=1.410, Y=-0.983, Z=-0.637 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.0449 dps (rate: 0.001795 dps/sample)
#      IMU2 Bias shift magnitude: 0.0951 dps (rate: 0.003805 dps/sample)
#
# ======================================================================
# Session: fist/test_data (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.173, Y=-1.103, Z=0.522 dps
#   IMU2 (Finger) Gyro Bias: X=1.602, Y=-0.394, Z=-0.636 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.468, Y=-1.155, Z=0.391 dps
#   IMU2 (Finger) Gyro Bias: X=1.777, Y=-0.550, Z=-0.812 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.3267 dps (rate: 0.013067 dps/sample)
#      IMU2 Bias shift magnitude: 0.2936 dps (rate: 0.011745 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.332, Y=-1.145, Z=0.381 dps
#   IMU2 (Finger) Gyro Bias: X=1.667, Y=-0.616, Z=-0.925 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1366 dps (rate: 0.005463 dps/sample)
#      IMU2 Bias shift magnitude: 0.1711 dps (rate: 0.006844 dps/sample)
#
# ======================================================================
# Session: fist/validation_data (2 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.296, Y=-1.498, Z=0.476 dps
#   IMU2 (Finger) Gyro Bias: X=1.594, Y=-0.421, Z=-0.912 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.315, Y=-1.578, Z=0.510 dps
#   IMU2 (Finger) Gyro Bias: X=1.620, Y=-0.447, Z=-0.772 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.0889 dps (rate: 0.003554 dps/sample)
#      IMU2 Bias shift magnitude: 0.1442 dps (rate: 0.005769 dps/sample)
#
# ======================================================================
# Session: jerk_down/session_1782829902 (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.331, Y=-1.411, Z=0.437 dps
#   IMU2 (Finger) Gyro Bias: X=1.206, Y=-1.057, Z=-0.284 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.404, Y=-1.479, Z=0.379 dps
#   IMU2 (Finger) Gyro Bias: X=1.420, Y=-0.960, Z=-0.604 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1148 dps (rate: 0.004593 dps/sample)
#      IMU2 Bias shift magnitude: 0.3972 dps (rate: 0.015887 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.336, Y=-1.483, Z=0.352 dps
#   IMU2 (Finger) Gyro Bias: X=1.366, Y=-0.941, Z=-0.538 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.0725 dps (rate: 0.002901 dps/sample)
#      IMU2 Bias shift magnitude: 0.0875 dps (rate: 0.003502 dps/sample)
#
# ======================================================================
# Session: jerk_down/session_1782846044 (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.245, Y=-1.212, Z=0.398 dps
#   IMU2 (Finger) Gyro Bias: X=1.627, Y=-0.619, Z=-0.961 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.163, Y=-1.515, Z=0.410 dps
#   IMU2 (Finger) Gyro Bias: X=1.665, Y=-0.709, Z=-0.889 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.3148 dps (rate: 0.012593 dps/sample)
#      IMU2 Bias shift magnitude: 0.1211 dps (rate: 0.004842 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.197, Y=-1.509, Z=0.366 dps
#   IMU2 (Finger) Gyro Bias: X=1.301, Y=-0.879, Z=-1.128 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.0566 dps (rate: 0.002265 dps/sample)
#      IMU2 Bias shift magnitude: 0.4676 dps (rate: 0.018705 dps/sample)
#
# ======================================================================
# Session: jerk_down/test_data (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.569, Y=-1.402, Z=0.375 dps
#   IMU2 (Finger) Gyro Bias: X=1.626, Y=-0.437, Z=-0.842 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.466, Y=-1.243, Z=0.583 dps
#   IMU2 (Finger) Gyro Bias: X=1.594, Y=-0.517, Z=-0.829 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.2807 dps (rate: 0.011227 dps/sample)
#      IMU2 Bias shift magnitude: 0.0867 dps (rate: 0.003468 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.373, Y=-1.292, Z=0.551 dps
#   IMU2 (Finger) Gyro Bias: X=2.049, Y=-0.780, Z=-1.067 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1098 dps (rate: 0.004391 dps/sample)
#      IMU2 Bias shift magnitude: 0.5777 dps (rate: 0.023110 dps/sample)
#
# ======================================================================
# Session: jerk_down/validation_data (2 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.174, Y=-1.470, Z=0.541 dps
#   IMU2 (Finger) Gyro Bias: X=1.388, Y=-0.445, Z=-0.861 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.341, Y=-1.658, Z=0.519 dps
#   IMU2 (Finger) Gyro Bias: X=1.382, Y=-0.485, Z=-0.721 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.2524 dps (rate: 0.010098 dps/sample)
#      IMU2 Bias shift magnitude: 0.1456 dps (rate: 0.005824 dps/sample)
#
# ======================================================================
# Session: jerk_up/session_1782829539 (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.288, Y=-1.237, Z=0.415 dps
#   IMU2 (Finger) Gyro Bias: X=1.487, Y=-1.953, Z=-0.494 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.247, Y=-1.413, Z=0.208 dps
#   IMU2 (Finger) Gyro Bias: X=1.480, Y=-1.327, Z=-0.528 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.2747 dps (rate: 0.010987 dps/sample)
#      IMU2 Bias shift magnitude: 0.6276 dps (rate: 0.025105 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.298, Y=-1.221, Z=0.380 dps
#   IMU2 (Finger) Gyro Bias: X=1.374, Y=-1.078, Z=-0.488 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.2632 dps (rate: 0.010530 dps/sample)
#      IMU2 Bias shift magnitude: 0.2736 dps (rate: 0.010945 dps/sample)
#
# ======================================================================
# Session: jerk_up/session_1782846444 (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.227, Y=-1.387, Z=0.313 dps
#   IMU2 (Finger) Gyro Bias: X=1.755, Y=-0.597, Z=-0.831 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.294, Y=-1.705, Z=0.329 dps
#   IMU2 (Finger) Gyro Bias: X=1.664, Y=-0.807, Z=-0.726 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.3248 dps (rate: 0.012993 dps/sample)
#      IMU2 Bias shift magnitude: 0.2520 dps (rate: 0.010081 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.238, Y=-1.440, Z=0.424 dps
#   IMU2 (Finger) Gyro Bias: X=1.590, Y=-0.927, Z=-0.684 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.2871 dps (rate: 0.011482 dps/sample)
#      IMU2 Bias shift magnitude: 0.1466 dps (rate: 0.005864 dps/sample)
#
# ======================================================================
# Session: jerk_up/test_data (2 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.379, Y=-1.351, Z=0.383 dps
#   IMU2 (Finger) Gyro Bias: X=1.730, Y=-0.872, Z=-0.729 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.326, Y=-1.758, Z=0.291 dps
#   IMU2 (Finger) Gyro Bias: X=1.609, Y=-0.691, Z=-0.655 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.4204 dps (rate: 0.016815 dps/sample)
#      IMU2 Bias shift magnitude: 0.2289 dps (rate: 0.009158 dps/sample)
#
# ======================================================================
# Session: jerk_up/validation_data (2 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.269, Y=-1.555, Z=0.527 dps
#   IMU2 (Finger) Gyro Bias: X=1.624, Y=-0.150, Z=-0.521 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.244, Y=-1.807, Z=0.409 dps
#   IMU2 (Finger) Gyro Bias: X=1.451, Y=-0.458, Z=-0.443 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.2793 dps (rate: 0.011171 dps/sample)
#      IMU2 Bias shift magnitude: 0.3619 dps (rate: 0.014474 dps/sample)
#
# ======================================================================
# Session: none/session_1782831291 (7 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.352, Y=-1.093, Z=0.388 dps
#   IMU2 (Finger) Gyro Bias: X=1.422, Y=-1.375, Z=-0.673 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.389, Y=-1.257, Z=0.388 dps
#   IMU2 (Finger) Gyro Bias: X=1.429, Y=-1.163, Z=-0.665 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1675 dps (rate: 0.006701 dps/sample)
#      IMU2 Bias shift magnitude: 0.2122 dps (rate: 0.008489 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.447, Y=-1.314, Z=0.318 dps
#   IMU2 (Finger) Gyro Bias: X=1.478, Y=-0.956, Z=-0.739 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1074 dps (rate: 0.004294 dps/sample)
#      IMU2 Bias shift magnitude: 0.2254 dps (rate: 0.009018 dps/sample)
#
# Calibration at sample 75 (calibration_3.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.442, Y=-1.408, Z=0.328 dps
#   IMU2 (Finger) Gyro Bias: X=1.531, Y=-1.222, Z=-0.758 dps
#   -> Drift since sample 50 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.0944 dps (rate: 0.003777 dps/sample)
#      IMU2 Bias shift magnitude: 0.2724 dps (rate: 0.010897 dps/sample)
#
# Calibration at sample 100 (calibration_4.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.318, Y=-1.264, Z=0.402 dps
#   IMU2 (Finger) Gyro Bias: X=1.457, Y=-0.893, Z=-0.718 dps
#   -> Drift since sample 75 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.2034 dps (rate: 0.008138 dps/sample)
#      IMU2 Bias shift magnitude: 0.3397 dps (rate: 0.013589 dps/sample)
#
# Calibration at sample 125 (calibration_5.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.313, Y=-1.380, Z=0.366 dps
#   IMU2 (Finger) Gyro Bias: X=1.512, Y=-1.293, Z=-0.787 dps
#   -> Drift since sample 100 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1213 dps (rate: 0.004852 dps/sample)
#      IMU2 Bias shift magnitude: 0.4090 dps (rate: 0.016360 dps/sample)
#
# Calibration at sample 150 (calibration_6.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.423, Y=-1.422, Z=0.413 dps
#   IMU2 (Finger) Gyro Bias: X=1.594, Y=-1.040, Z=-0.615 dps
#   -> Drift since sample 125 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1266 dps (rate: 0.005064 dps/sample)
#      IMU2 Bias shift magnitude: 0.3165 dps (rate: 0.012661 dps/sample)
#
# ======================================================================
# Session: none/session_1782831658 (2 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.385, Y=-1.165, Z=0.437 dps
#   IMU2 (Finger) Gyro Bias: X=1.537, Y=-1.023, Z=-0.710 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.399, Y=-1.120, Z=0.451 dps
#   IMU2 (Finger) Gyro Bias: X=1.611, Y=-1.010, Z=-0.630 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.0498 dps (rate: 0.001993 dps/sample)
#      IMU2 Bias shift magnitude: 0.1097 dps (rate: 0.004388 dps/sample)
#
# ======================================================================
# Session: none/session_1782846877 (4 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.102, Y=-1.506, Z=0.393 dps
#   IMU2 (Finger) Gyro Bias: X=1.643, Y=-0.942, Z=-0.789 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.147, Y=-1.457, Z=0.421 dps
#   IMU2 (Finger) Gyro Bias: X=1.723, Y=-1.120, Z=-0.772 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.0719 dps (rate: 0.002876 dps/sample)
#      IMU2 Bias shift magnitude: 0.1964 dps (rate: 0.007854 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.218, Y=-1.412, Z=0.455 dps
#   IMU2 (Finger) Gyro Bias: X=1.558, Y=-0.569, Z=-0.718 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.0909 dps (rate: 0.003636 dps/sample)
#      IMU2 Bias shift magnitude: 0.5783 dps (rate: 0.023131 dps/sample)
#
# Calibration at sample 75 (calibration_3.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.267, Y=-1.363, Z=0.402 dps
#   IMU2 (Finger) Gyro Bias: X=1.708, Y=-0.674, Z=-0.703 dps
#   -> Drift since sample 50 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.0868 dps (rate: 0.003474 dps/sample)
#      IMU2 Bias shift magnitude: 0.1842 dps (rate: 0.007366 dps/sample)
#
# ======================================================================
# Session: none/test_data (7 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.277, Y=-1.441, Z=0.488 dps
#   IMU2 (Finger) Gyro Bias: X=1.494, Y=-0.837, Z=-0.636 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.272, Y=-1.487, Z=0.372 dps
#   IMU2 (Finger) Gyro Bias: X=1.470, Y=-0.316, Z=-0.534 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1253 dps (rate: 0.005013 dps/sample)
#      IMU2 Bias shift magnitude: 0.5311 dps (rate: 0.021245 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.215, Y=-1.518, Z=0.449 dps
#   IMU2 (Finger) Gyro Bias: X=1.490, Y=-0.322, Z=-0.670 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1010 dps (rate: 0.004038 dps/sample)
#      IMU2 Bias shift magnitude: 0.1370 dps (rate: 0.005481 dps/sample)
#
# Calibration at sample 75 (calibration_3.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.278, Y=-1.378, Z=0.505 dps
#   IMU2 (Finger) Gyro Bias: X=1.494, Y=-0.425, Z=-0.647 dps
#   -> Drift since sample 50 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1630 dps (rate: 0.006522 dps/sample)
#      IMU2 Bias shift magnitude: 0.1053 dps (rate: 0.004213 dps/sample)
#
# Calibration at sample 100 (calibration_4.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.233, Y=-1.504, Z=0.472 dps
#   IMU2 (Finger) Gyro Bias: X=1.491, Y=-0.559, Z=-0.703 dps
#   -> Drift since sample 75 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1378 dps (rate: 0.005514 dps/sample)
#      IMU2 Bias shift magnitude: 0.1458 dps (rate: 0.005834 dps/sample)
#
# Calibration at sample 125 (calibration_5.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.013, Y=-1.553, Z=0.398 dps
#   IMU2 (Finger) Gyro Bias: X=1.437, Y=-0.413, Z=-0.684 dps
#   -> Drift since sample 100 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.2378 dps (rate: 0.009513 dps/sample)
#      IMU2 Bias shift magnitude: 0.1573 dps (rate: 0.006291 dps/sample)
#
# Calibration at sample 150 (calibration_6.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.176, Y=-1.632, Z=0.402 dps
#   IMU2 (Finger) Gyro Bias: X=1.731, Y=-0.372, Z=-0.766 dps
#   -> Drift since sample 125 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1812 dps (rate: 0.007249 dps/sample)
#      IMU2 Bias shift magnitude: 0.3084 dps (rate: 0.012336 dps/sample)
#
# ======================================================================
# Session: none/validation_data (4 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.293, Y=-1.590, Z=0.499 dps
#   IMU2 (Finger) Gyro Bias: X=1.342, Y=-0.246, Z=-0.584 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.340, Y=-1.719, Z=0.448 dps
#   IMU2 (Finger) Gyro Bias: X=1.487, Y=-0.536, Z=-0.687 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1469 dps (rate: 0.005878 dps/sample)
#      IMU2 Bias shift magnitude: 0.3411 dps (rate: 0.013642 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.101, Y=-1.539, Z=0.424 dps
#   IMU2 (Finger) Gyro Bias: X=1.398, Y=-0.495, Z=-0.677 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.3006 dps (rate: 0.012022 dps/sample)
#      IMU2 Bias shift magnitude: 0.0984 dps (rate: 0.003937 dps/sample)
#
# Calibration at sample 75 (calibration_3.csv):
#   IMU1 (Wrist) Gyro Bias: X=-3.757, Y=1.439, Z=2.266 dps
#   IMU2 (Finger) Gyro Bias: X=2.826, Y=0.466, Z=1.452 dps
#   -> Drift since sample 50 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 5.0628 dps (rate: 0.202510 dps/sample)
#      IMU2 Bias shift magnitude: 2.7374 dps (rate: 0.109495 dps/sample)
#
# ======================================================================
# Session: swipe_left/session_1782845000 (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.078, Y=-1.468, Z=0.249 dps
#   IMU2 (Finger) Gyro Bias: X=0.777, Y=-1.093, Z=-0.382 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.015, Y=-1.754, Z=0.361 dps
#   IMU2 (Finger) Gyro Bias: X=1.586, Y=-0.586, Z=-0.667 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.3133 dps (rate: 0.012532 dps/sample)
#      IMU2 Bias shift magnitude: 0.9964 dps (rate: 0.039856 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=0.322, Y=-1.898, Z=0.252 dps
#   IMU2 (Finger) Gyro Bias: X=1.731, Y=-0.587, Z=-0.769 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.3823 dps (rate: 0.015292 dps/sample)
#      IMU2 Bias shift magnitude: 0.1770 dps (rate: 0.007081 dps/sample)
#
# ======================================================================
# Session: swipe_left/test_data (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.253, Y=-1.538, Z=0.294 dps
#   IMU2 (Finger) Gyro Bias: X=1.637, Y=-0.717, Z=-0.746 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.161, Y=-1.559, Z=0.250 dps
#   IMU2 (Finger) Gyro Bias: X=1.615, Y=-0.667, Z=-0.768 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1043 dps (rate: 0.004173 dps/sample)
#      IMU2 Bias shift magnitude: 0.0591 dps (rate: 0.002363 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.016, Y=-1.413, Z=0.391 dps
#   IMU2 (Finger) Gyro Bias: X=1.639, Y=-0.515, Z=-0.917 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.2487 dps (rate: 0.009948 dps/sample)
#      IMU2 Bias shift magnitude: 0.2142 dps (rate: 0.008566 dps/sample)
#
# ======================================================================
# Session: swipe_left/validation_data (2 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.107, Y=-1.438, Z=0.500 dps
#   IMU2 (Finger) Gyro Bias: X=1.485, Y=-0.523, Z=-0.684 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.183, Y=-1.690, Z=0.432 dps
#   IMU2 (Finger) Gyro Bias: X=1.747, Y=-0.367, Z=-0.458 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.2713 dps (rate: 0.010852 dps/sample)
#      IMU2 Bias shift magnitude: 0.3797 dps (rate: 0.015187 dps/sample)
#
# ======================================================================
# Session: swipe_right/session_1782676777 (2 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.556, Y=-0.865, Z=0.485 dps
#   IMU2 (Finger) Gyro Bias: X=1.617, Y=-1.568, Z=-0.051 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.660, Y=-0.903, Z=0.458 dps
#   IMU2 (Finger) Gyro Bias: X=1.751, Y=-1.487, Z=0.052 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1147 dps (rate: 0.004586 dps/sample)
#      IMU2 Bias shift magnitude: 0.1877 dps (rate: 0.007508 dps/sample)
#
# ======================================================================
# Session: swipe_right/session_1782830800 (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.534, Y=-1.039, Z=0.419 dps
#   IMU2 (Finger) Gyro Bias: X=1.470, Y=-1.060, Z=-0.604 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.368, Y=-1.429, Z=0.421 dps
#   IMU2 (Finger) Gyro Bias: X=1.461, Y=-1.102, Z=-0.700 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.4235 dps (rate: 0.016938 dps/sample)
#      IMU2 Bias shift magnitude: 0.1054 dps (rate: 0.004214 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.290, Y=-1.476, Z=0.361 dps
#   IMU2 (Finger) Gyro Bias: X=1.502, Y=-1.055, Z=-0.761 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1088 dps (rate: 0.004353 dps/sample)
#      IMU2 Bias shift magnitude: 0.0869 dps (rate: 0.003475 dps/sample)
#
# ======================================================================
# Session: swipe_right/test_data (3 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.189, Y=-1.569, Z=0.275 dps
#   IMU2 (Finger) Gyro Bias: X=1.679, Y=-0.583, Z=-0.962 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.336, Y=-1.566, Z=0.266 dps
#   IMU2 (Finger) Gyro Bias: X=1.541, Y=-0.694, Z=-0.642 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.1480 dps (rate: 0.005921 dps/sample)
#      IMU2 Bias shift magnitude: 0.3662 dps (rate: 0.014647 dps/sample)
#
# Calibration at sample 50 (calibration_2.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.041, Y=-1.542, Z=0.416 dps
#   IMU2 (Finger) Gyro Bias: X=1.610, Y=-0.629, Z=-0.714 dps
#   -> Drift since sample 25 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.3316 dps (rate: 0.013265 dps/sample)
#      IMU2 Bias shift magnitude: 0.1188 dps (rate: 0.004751 dps/sample)
#
# ======================================================================
# Session: swipe_right/validation_data (2 calibrations)
# ======================================================================
#
# Calibration at sample 0 (calibration_0.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.221, Y=-1.581, Z=0.451 dps
#   IMU2 (Finger) Gyro Bias: X=1.425, Y=-0.490, Z=-0.530 dps
#
# Calibration at sample 25 (calibration_1.csv):
#   IMU1 (Wrist) Gyro Bias: X=-0.030, Y=-2.057, Z=0.438 dps
#   IMU2 (Finger) Gyro Bias: X=1.516, Y=-0.519, Z=-0.675 dps
#   -> Drift since sample 0 (diff: 25 samples):
#      IMU1 Bias shift magnitude: 0.5129 dps (rate: 0.020518 dps/sample)
#      IMU2 Bias shift magnitude: 0.1733 dps (rate: 0.006932 dps/sample)

# %%
# Plot drift curves for multi-calibration sessions
if multi_cal_sessions:
    fig, axs = plt.subplots(len(multi_cal_sessions) * 2, 1, figsize=(12, 5 * len(multi_cal_sessions) * 2), sharex=False)
    if isinstance(axs, np.ndarray):
        axs = axs.flatten()
    else:
        axs = np.array([axs])
        
    plot_idx = 0
    for (gesture, session), records in multi_cal_sessions.items():
        sample_counts = [r['sample_count'] for r in records]
        
        # IMU1 Biases
        imu1_x = [r['imu1_bias']['X'] for r in records]
        imu1_y = [r['imu1_bias']['Y'] for r in records]
        imu1_z = [r['imu1_bias']['Z'] for r in records]
        
        # Plot IMU1
        ax = axs[plot_idx]
        ax.plot(sample_counts, imu1_x, 'o-', label='Bias X', color='#1f77b4')
        ax.plot(sample_counts, imu1_y, 'o-', label='Bias Y', color='#ff7f0e')
        ax.plot(sample_counts, imu1_z, 'o-', label='Bias Z', color='#2ca02c')
        ax.set_title(f"IMU1 (Wrist) Gyro Bias Drift - {gesture}/{session}")
        ax.set_xlabel("Recorded Samples")
        ax.set_ylabel("Zero-Bias (dps)")
        ax.grid(True, linestyle='--')
        ax.legend()
        plot_idx += 1
        
        # IMU2 Biases
        imu2_x = [r['imu2_bias']['X'] for r in records]
        imu2_y = [r['imu2_bias']['Y'] for r in records]
        imu2_z = [r['imu2_bias']['Z'] for r in records]
        
        # Plot IMU2
        ax = axs[plot_idx]
        ax.plot(sample_counts, imu2_x, 's-', label='Bias X', color='#d62728')
        ax.plot(sample_counts, imu2_y, 's-', label='Bias Y', color='#9467bd')
        ax.plot(sample_counts, imu2_z, 's-', label='Bias Z', color='#8c564b')
        ax.set_title(f"IMU2 (Finger) Gyro Bias Drift - {gesture}/{session}")
        ax.set_xlabel("Recorded Samples")
        ax.set_ylabel("Zero-Bias (dps)")
        ax.grid(True, linestyle='--')
        ax.legend()
        plot_idx += 1
        
    plt.tight_layout()
    plt.show()
else:
    print("No multi-calibration sessions found to plot.")
